# %% [markdown]
# The NOAA HRRR is a real-time 3km resolution, hourly updated, cloud-resolving, convection-allowing atmospheric model, initialized by 3km grids with 3km radar assimilation.
#
# This notebook provides an example of accessing HRRR data, including (1) finding the data file corresponding to a date and time, (2) retrieving a portion of that file from blob storage which includes the surface temperature variable, (3) opening the file using the xarray library, and (4) rendering an image of the forecast.

# %% [markdown]
# This dataset is documented at http://aka.ms/ai4edata-hrrr.

# %%
import io
from datetime import date, timedelta

import xarray as xr
import requests
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import cmocean

# Not used directly, but used via xarray
import cfgrib

# %%
# Constants for creating the full URL
blob_container = "https://noaahrrr.blob.core.windows.net/hrrr"
sector = "conus"
yesterday = date.today() - timedelta(days=1)
cycle = 12          # noon
forecast_hour = 1   # offset from cycle time
product = "wrfsfcf" # 2D surface levels

# Put it all together
file_path = f"hrrr.t{cycle:02}z.{product}{forecast_hour:02}.grib2"
url = f"{blob_container}/hrrr.{yesterday:%Y%m%d}/{sector}/{file_path}"

print(url)
# Out:
# https://noaahrrr.blob.core.windows.net/hrrr/hrrr.20230124/conus/hrrr.t12z.wrfsfcf01.grib2

# %%
(yesterday)
# Out:
# datetime.date(2023, 1, 24)

# %%
# Fetch the idx file by appending the .idx file extension to our already formatted URL
r = requests.get(f"{url}.idx")
idx = r.text.splitlines()

# Take a peek at the content of the index
print(*idx[1:150], sep="\n")
# Out:
# 2:309576:d=2023012412:RETOP:cloud top:1 hour fcst:
# 3:458385:d=2023012412:var discipline=0 center=7 local_table=1 parmcat=16 parm=201:entire atmosphere:1 hour fcst:
# 4:902674:d=2023012412:VIL:entire atmosphere:1 hour fcst:
# 5:1135417:d=2023012412:VIS:surface:1 hour fcst:
# 6:2556391:d=2023012412:REFD:1000 m above ground:1 hour fcst:
# 7:2749634:d=2023012412:REFD:4000 m above ground:1 hour fcst:
# 8:2844965:d=2023012412:REFD:263 K level:1 hour fcst:
# 9:2999675:d=2023012412:GUST:surface:1 hour fcst:
# 10:4288602:d=2023012412:UGRD:250 mb:1 hour fcst:
# 11:5065247:d=2023012412:VGRD:250 mb:1 hour fcst:
# 12:5791980:d=2023012412:UGRD:300 mb:1 hour fcst:
# 13:6564212:d=2023012412:VGRD:300 mb:1 hour fcst:
# 14:7299987:d=2023012412:HGT:500 mb:1 hour fcst:
# 15:8043354:d=2023012412:TMP:500 mb:1 hour fcst:
# 16:8594082:d=2023012412:DPT:500 mb:1 hour fcst:
# 17:9522074:d=2023012412:UGRD:500 mb:1 hour fcst:
# 18:10114741:d=2023012412:VGRD:500 mb:1 hour fcst:
# 19:10697373:d=2023012412:HGT:700 mb:1 hour fcst:
# 20:11449234:d=2023012412:TMP:700 mb:1 hour fcst:
# 21:12012685:d=2023012412:DPT:700 mb:1 hour fcst:
# 22:13001580:d=2023012412:DZDT:700 mb:1 hour fcst:
# 23:13989844:d=2023012412:UGRD:700 mb:1 hour fcst:
# 24:14599733:d=2023012412:VGRD:700 mb:1 hour fcst:
# 25:15198794:d=2023012412:HGT:850 mb:1 hour fcst:
# 26:15976912:d=2023012412:TMP:850 mb:1 hour fcst:
# 27:16578720:d=2023012412:DPT:850 mb:1 hour fcst:
# 28:17707991:d=2023012412:UGRD:850 mb:1 hour fcst:
# 29:18341430:d=2023012412:VGRD:850 mb:1 hour fcst:
# 30:18964319:d=2023012412:TMP:925 mb:1 hour fcst:
# 31:19574406:d=2023012412:DPT:925 mb:1 hour fcst:
# 32:20703396:d=2023012412:UGRD:925 mb:1 hour fcst:
# 33:21345244:d=2023012412:VGRD:925 mb:1 hour fcst:
# 34:21966700:d=2023012412:TMP:1000 mb:1 hour fcst:
# 35:22593503:d=2023012412:DPT:1000 mb:1 hour fcst:
# 36:23709879:d=2023012412:UGRD:1000 mb:1 hour fcst:
# 37:24359471:d=2023012412:VGRD:1000 mb:1 hour fcst:
# 38:24976905:d=2023012412:MAXUVV:100-1000 mb above ground:0-1 hour max fcst:
# 39:25693498:d=2023012412:MAXDVV:100-1000 mb above ground:0-1 hour max fcst:
# 40:26416725:d=2023012412:DZDT:0.5-0.8 sigma layer:0-1 hour ave fcst:
# 41:27092377:d=2023012412:MSLMA:mean sea level:1 hour fcst:
# 42:27742047:d=2023012412:HGT:1000 mb:1 hour fcst:
# 43:28535321:d=2023012412:MAXREF:1000 m above ground:0-1 hour max fcst:
# 44:28803994:d=2023012412:REFD:263 K level:0-1 hour max fcst:
# 45:29049529:d=2023012412:MXUPHL:5000-2000 m above ground:0-1 hour max fcst:
# 46:29163280:d=2023012412:MNUPHL:5000-2000 m above ground:0-1 hour min fcst:
# 47:29268199:d=2023012412:MXUPHL:2000-0 m above ground:0-1 hour max fcst:
# 48:29550370:d=2023012412:MNUPHL:2000-0 m above ground:0-1 hour min fcst:
# 49:29741493:d=2023012412:MXUPHL:3000-0 m above ground:0-1 hour max fcst:
# 50:29832354:d=2023012412:MNUPHL:3000-0 m above ground:0-1 hour min fcst:
# 51:30050990:d=2023012412:RELV:2000-0 m above ground:0-1 hour max fcst:
# 52:32308356:d=2023012412:RELV:1000-0 m above ground:0-1 hour max fcst:
# 53:34680894:d=2023012412:HAIL:entire atmosphere:0-1 hour max fcst:
# 54:34852146:d=2023012412:HAIL:0.1 sigma level:0-1 hour max fcst:
# 55:34943436:d=2023012412:HAIL:surface:0-1 hour max fcst:
# 56:34943648:d=2023012412:TCOLG:entire atmosphere (considered as a single layer):0-1 hour max fcst:
# 57:35008945:d=2023012412:LTNGSD:1 m above ground:1 hour fcst:
# 58:35009133:d=2023012412:LTNGSD:2 m above ground:1 hour fcst:
# 59:35105746:d=2023012412:LTNG:entire atmosphere:1 hour fcst:
# 60:35105934:d=2023012412:UGRD:80 m above ground:1 hour fcst:
# 61:36287630:d=2023012412:VGRD:80 m above ground:1 hour fcst:
# 62:37442444:d=2023012412:PRES:surface:1 hour fcst:
# 63:38953538:d=2023012412:HGT:surface:1 hour fcst:
# 64:41107233:d=2023012412:TMP:surface:1 hour fcst:
# 65:42500889:d=2023012412:ASNOW:surface:0-1 hour acc fcst:
# 66:42806615:d=2023012412:MSTAV:0 m underground:1 hour fcst:
# 67:44094311:d=2023012412:CNWAT:surface:1 hour fcst:
# 68:44372368:d=2023012412:WEASD:surface:1 hour fcst:
# 69:45441344:d=2023012412:SNOWC:surface:1 hour fcst:
# 70:45685492:d=2023012412:SNOD:surface:1 hour fcst:
# 71:46540710:d=2023012412:TMP:2 m above ground:1 hour fcst:
# 72:47800379:d=2023012412:POT:2 m above ground:1 hour fcst:
# 73:49057085:d=2023012412:SPFH:2 m above ground:1 hour fcst:
# 74:50451526:d=2023012412:DPT:2 m above ground:1 hour fcst:
# 75:51728983:d=2023012412:RH:2 m above ground:1 hour fcst:
# 76:53383529:d=2023012412:MASSDEN:8 m above ground:1 hour fcst:
# 77:53993256:d=2023012412:UGRD:10 m above ground:1 hour fcst:
# 78:56374871:d=2023012412:VGRD:10 m above ground:1 hour fcst:
# 79:58756486:d=2023012412:WIND:10 m above ground:0-1 hour max fcst:
# 80:60032416:d=2023012412:MAXUW:10 m above ground:0-1 hour max fcst:
# 81:61415113:d=2023012412:MAXVW:10 m above ground:0-1 hour max fcst:
# 82:62790759:d=2023012412:CPOFP:surface:1 hour fcst:
# 83:62885996:d=2023012412:PRATE:surface:1 hour fcst:
# 84:62936062:d=2023012412:APCP:surface:0-1 hour acc fcst:
# 85:63287632:d=2023012412:WEASD:surface:0-1 hour acc fcst:
# 86:63603639:d=2023012412:FROZR:surface:0-1 hour acc fcst:
# 87:63686515:d=2023012412:FRZR:surface:0-1 hour acc fcst:
# 88:63851236:d=2023012412:SSRUN:surface:0-1 hour acc fcst:
# 89:63861593:d=2023012412:BGRUN:surface:0-1 hour acc fcst:
# 90:63863075:d=2023012412:CSNOW:surface:1 hour fcst:
# 91:63907659:d=2023012412:CICEP:surface:1 hour fcst:
# 92:63909353:d=2023012412:CFRZR:surface:1 hour fcst:
# 93:63915355:d=2023012412:CRAIN:surface:1 hour fcst:
# 94:63940393:d=2023012412:SFCR:surface:1 hour fcst:
# 95:65863744:d=2023012412:FRICV:surface:1 hour fcst:
# 96:67092866:d=2023012412:SHTFL:surface:1 hour fcst:
# 97:68387885:d=2023012412:LHTFL:surface:1 hour fcst:
# 98:69550034:d=2023012412:VEG:surface:1 hour fcst:
# 99:70937405:d=2023012412:var discipline=2 center=7 local_table=1 parmcat=0 parm=231:surface:1 hour fcst:
# 100:72053542:d=2023012412:var discipline=2 center=7 local_table=1 parmcat=0 parm=232:surface:1 hour fcst:
# 101:72930476:d=2023012412:LAI:surface:1 hour fcst:
# 102:73604584:d=2023012412:GFLUX:surface:1 hour fcst:
# 103:74191593:d=2023012412:VGTYP:surface:1 hour fcst:
# 104:74974404:d=2023012412:LFTX:500-1000 mb:1 hour fcst:
# 105:76000676:d=2023012412:CAPE:surface:1 hour fcst:
# 106:76178603:d=2023012412:CIN:surface:1 hour fcst:
# 107:76403324:d=2023012412:PWAT:entire atmosphere (considered as a single layer):1 hour fcst:
# 108:77192074:d=2023012412:AOTK:entire atmosphere (considered as a single layer):1 hour fcst:
# 109:78204242:d=2023012412:COLMD:entire atmosphere (considered as a single layer):1 hour fcst:
# 110:79035530:d=2023012412:TCOLW:entire atmosphere:1 hour fcst:
# 111:80361924:d=2023012412:TCOLI:entire atmosphere:1 hour fcst:
# 112:81801355:d=2023012412:TCDC:boundary layer cloud layer:1 hour fcst:
# 113:82575365:d=2023012412:LCDC:low cloud layer:1 hour fcst:
# 114:83490603:d=2023012412:MCDC:middle cloud layer:1 hour fcst:
# 115:83873280:d=2023012412:HCDC:high cloud layer:1 hour fcst:
# 116:84218808:d=2023012412:TCDC:entire atmosphere:1 hour fcst:
# 117:85098571:d=2023012412:HGT:cloud ceiling:1 hour fcst:
# 118:86407687:d=2023012412:HGT:cloud base:1 hour fcst:
# 119:88982280:d=2023012412:PRES:cloud base:1 hour fcst:
# 120:89737842:d=2023012412:PRES:cloud top:1 hour fcst:
# 121:90395977:d=2023012412:HGT:cloud top:1 hour fcst:
# 122:91579113:d=2023012412:ULWRF:top of atmosphere:1 hour fcst:
# 123:93439810:d=2023012412:DSWRF:surface:1 hour fcst:
# 124:94070981:d=2023012412:DLWRF:surface:1 hour fcst:
# 125:96191579:d=2023012412:USWRF:surface:1 hour fcst:
# 126:96654258:d=2023012412:ULWRF:surface:1 hour fcst:
# 127:98316003:d=2023012412:CFNSF:surface:1 hour fcst:
# 128:98318323:d=2023012412:VBDSF:surface:1 hour fcst:
# 129:99053503:d=2023012412:VDDSF:surface:1 hour fcst:
# 130:99680698:d=2023012412:USWRF:top of atmosphere:1 hour fcst:
# 131:100306574:d=2023012412:HLCY:3000-0 m above ground:1 hour fcst:
# 132:101547729:d=2023012412:HLCY:1000-0 m above ground:1 hour fcst:
# 133:102762517:d=2023012412:USTM:0-6000 m above ground:1 hour fcst:
# 134:103733508:d=2023012412:VSTM:0-6000 m above ground:1 hour fcst:
# 135:104695783:d=2023012412:VUCSH:0-1000 m above ground:1 hour fcst:
# 136:107315540:d=2023012412:VVCSH:0-1000 m above ground:1 hour fcst:
# 137:109697155:d=2023012412:VUCSH:0-6000 m above ground:1 hour fcst:
# 138:112078770:d=2023012412:VVCSH:0-6000 m above ground:1 hour fcst:
# 139:114698527:d=2023012412:HGT:0C isotherm:1 hour fcst:
# 140:116553406:d=2023012412:RH:0C isotherm:1 hour fcst:
# 141:117435418:d=2023012412:PRES:0C isotherm:1 hour fcst:
# 142:118457307:d=2023012412:HGT:highest tropospheric freezing level:1 hour fcst:
# 143:119316200:d=2023012412:RH:highest tropospheric freezing level:1 hour fcst:
# 144:120147097:d=2023012412:PRES:highest tropospheric freezing level:1 hour fcst:
# 145:121102863:d=2023012412:HGT:263 K level:1 hour fcst:
# 146:121876610:d=2023012412:HGT:253 K level:1 hour fcst:
# 147:122573027:d=2023012412:4LFTX:180-0 mb above ground:1 hour fcst:
# 148:123518752:d=2023012412:CAPE:180-0 mb above ground:1 hour fcst:
# 149:123722162:d=2023012412:CIN:180-0 mb above ground:1 hour fcst:
# 150:123937360:d=2023012412:HPBL:surface:1 hour fcst:

# %%
# You can see it has a 1-indexed base line number, staring byte position, date, variable, atmosphere level,
# and forecast description. The lines are colon-delimited. 

# Let's grab surface temperature `TMP:surface`.
sfc_temp_idx = [l for l in idx if ":TMP:surface" in l][0].split(":")
print("Surface temp line:", sfc_temp_idx)

# Pluck the byte offset from this line, plus the beginning offset of the next line
line_num = int(sfc_temp_idx[0])
range_start = sfc_temp_idx[1]

# The line number values are 1-indexed, so we don't need to increment it to get the next list index,
# but check we're not already reading the last line
next_line = idx[line_num].split(':') if line_num < len(idx) else None

# Pluck the start of the next byte offset, or nothing if we were on the last line
range_end = next_line[1] if next_line else None

print(f"Byte range: {range_start}-{range_end}")
# Out:
# Surface temp line: ['64', '41107233', 'd=2023012412', 'TMP', 'surface', '1 hour fcst', '']
# Byte range: 41107233-42500889

# %%
import tempfile
file = tempfile.NamedTemporaryFile(prefix="tmp_", delete=False)

headers = {"Range": f"bytes={range_start}-{range_end}"}
resp = requests.get(url, headers=headers, stream=True)

with file as f:
    f.write(resp.content)

# %%
print(tempfile.gettempdir())
# Out:
# /var/folders/4h/k9rc8jg13fxcn0m11yvndchr0000gn/T

# %%
ds = xr.open_dataset(file.name, engine='cfgrib', 
                     backend_kwargs={'indexpath':''})

# %%
ds.t.plot.hist(edgecolor="white")
plt.show()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (y: 1059, x: 1799)
# Coordinates:
#     time        datetime64[ns] 2023-01-24T12:00:00
#     step        timedelta64[ns] 01:00:00
#     surface     float64 0.0
#     latitude    (y, x) float64 21.14 21.15 21.15 21.16 ... 47.86 47.85 47.84
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] 2023-01-24T13:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     t           (y, x) float32 294.6 294.6 294.6 294.6 ... 273.7 273.8 273.9
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2023-01-25T15:27 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
ds.t.plot()

# %%
ds.coords
#ds.t.attrs
# Out:
# Coordinates:
#     time        datetime64[ns] 2023-01-24T12:00:00
#     step        timedelta64[ns] 01:00:00
#     surface     float64 0.0
#     latitude    (y, x) float64 21.14 21.15 21.15 21.16 ... 47.86 47.85 47.84
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] 2023-01-24T13:00:00

# %%
ds.attrs
# Out:
# {'GRIB_edition': 2,
#  'GRIB_centre': 'kwbc',
#  'GRIB_centreDescription': 'US National Weather Service - NCEP',
#  'GRIB_subCentre': 0,
#  'Conventions': 'CF-1.7',
#  'institution': 'US National Weather Service - NCEP',
#  'history': '2023-01-25T15:27 GRIB to CDM+CF via cfgrib-0.9.10.3/ecCodes-2.27.0 with {"source": "../../../../../var/folders/4h/k9rc8jg13fxcn0m11yvndchr0000gn/T/tmp_vxt3ka7e", "filter_by_keys": {}, "encode_cf": ["parameter", "time", "geography", "vertical"]}'}

# %%
attrs = ds.t.attrs

assert attrs['GRIB_gridType'] == 'lambert'

# Define the CRS with attributes from the temperate DataArray
prj_kwargs = dict(
    globe=ccrs.Globe(ellipse='sphere'),
    central_latitude=attrs['GRIB_LaDInDegrees'],
    central_longitude=attrs['GRIB_LoVInDegrees'],
    standard_parallels=(attrs['GRIB_Latin1InDegrees'],\
                        attrs['GRIB_Latin2InDegrees'])
)

prj = ccrs.LambertConformal(**prj_kwargs)

# %%
ds.latitude
# Out:
# <xarray.DataArray 'latitude' (y: 1059, x: 1799)>
# [1905141 values with dtype=float64]
# Coordinates:
#     time        datetime64[ns] 2023-01-24T12:00:00
#     step        timedelta64[ns] 01:00:00
#     surface     float64 0.0
#     latitude    (y, x) float64 ...
#     longitude   (y, x) float64 ...
#     valid_time  datetime64[ns] 2023-01-24T13:00:00
# Dimensions without coordinates: y, x
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude
#     long_name:      latitude

# %%
import numpy as np
ds.t.sel(x=35,y=1)
latitude_array = ds.coords['latitude']
x, y = np.where(latitude_array == 39.080319)
print(x,y)
# Out:
# [] []

# %%
# Ignore some matplotlib deprecation warnings
import warnings; warnings.simplefilter("ignore")

fig = plt.figure(figsize=(15,8))
ax = plt.axes(projection=prj)
plt_kwargs = dict(x='longitude', y='latitude', cmap=cmocean.cm.thermal, 
                  transform=ccrs.PlateCarree())

ds.t.plot(**plt_kwargs, ax=ax)
ax.coastlines(linewidth=0.5)
ax.add_feature(cfeature.STATES.with_scale('50m'), linewidth=0.5)
plt.show()

# %%
# Increase the dpi a bit for some crisper text
fig = plt.figure(figsize=(15,8), dpi=100)
ax = plt.axes(projection=prj)

# K to C
with xr.set_options(keep_attrs=True):
    t_c = ds.t - 273.15
    t_c.attrs["units"] = "C"

# Add some context and zoom to the SW
ax.coastlines(linewidth=0.5)
ax.add_feature(cfeature.STATES.with_scale('50m'), linewidth=0.5)
ax.set_extent([-121, -108, 33, 39], crs=ccrs.PlateCarree())

t_c.plot(**plt_kwargs, ax=ax)
d = ds.coords['valid_time'].values

plt.title(f"HRRR Surface Temperatures Valid {yesterday} {cycle + forecast_hour:02}:00 UTC")
plt.show()
